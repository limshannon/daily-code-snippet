# %%
import pandas as pd 
df = pd.read_csv( 'D:/deepLearning_day01_04/leaf-classification/sample_submission.csv/sample_submission.csv')
df
# Out:
#        id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 0       4         0.010101         0.010101   0.010101     0.010101
# 1       7         0.010101         0.010101   0.010101     0.010101
# 2       9         0.010101         0.010101   0.010101     0.010101
# 3      12         0.010101         0.010101   0.010101     0.010101
# 4      13         0.010101         0.010101   0.010101     0.010101
# ..    ...              ...              ...        ...          ...
# 589  1576         0.010101         0.010101   0.010101     0.010101
# 590  1577         0.010101         0.010101   0.010101     0.010101
# 591  1579         0.010101         0.010101   0.010101     0.010101
# 592  1580         0.010101         0.010101   0.010101     0.010101
# 593  1583         0.010101         0.010101   0.010101     0.010101
#
#      Acer_Palmatum  Acer_Pictum  Acer_Platanoids  Acer_Rubrum  Acer_Rufinerve  \
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def warn(*args, **kwargs): pass
import warnings
warnings.warn = warn

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit

train = pd.read_csv('D:/deepLearning_day01_04/leaf-classification/train.csv/train.csv')
test = pd.read_csv('D:/deepLearning_day01_04/leaf-classification/test.csv/test.csv')
train
# Out:
#        id                species   margin1   margin2   margin3   margin4  \
# 0       1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1       2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2       3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3       5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4       6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
# ..    ...                    ...       ...       ...       ...       ...
# 985  1575   Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906
# 986  1578            Acer_Pictum  0.001953  0.003906  0.021484  0.107420
# 987  1581     Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484
# 988  1582          Quercus_Rubra  0.000000  0.000000  0.046875  0.056641
# 989  1584         Quercus_Afares  0.023438  0.019531  0.031250  0.015625
#
#       margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# ...

# %%
def encode(train, test):
    le = LabelEncoder().fit(train.species) 
    labels = le.transform(train.species)           # encode species strings
    classes = list(le.classes_)                    # save column names for submission
    test_ids = test.id                             # save test ids for submission
    
    train = train.drop(['species', 'id'], axis=1)  
    test = test.drop(['id'], axis=1)
    
    return train, labels, test, test_ids, classes

train, labels, test, test_ids, classes = encode(train, test)
train.head(1)
# Out:
#     margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0  0.007812  0.023438  0.023438  0.003906  0.011719  0.009766  0.027344
#
#    margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# 0      0.0  0.001953  0.033203  ...   0.007812        0.0    0.00293
#
#    texture58  texture59  texture60  texture61  texture62  texture63  texture64
# 0    0.00293   0.035156        0.0        0.0   0.004883        0.0   0.025391
#
# [1 rows x 192 columns]

# %%
labels
# Out:
# array([ 3, 49, 65, 94, 84, 40, 54, 78, 53, 89, 98, 16, 74, 50, 58, 31, 43,
#         4, 75, 44, 83, 84, 13, 66, 15,  6, 73, 22, 73, 31, 36, 27, 94, 88,
#        12, 28, 21, 25, 20, 60, 84, 65, 69, 58, 23, 76, 18, 52, 54,  9, 48,
#        47, 64, 81, 83, 36, 58, 21, 81, 20, 62, 88, 34, 92, 79, 82, 20, 32,
#         4, 84, 36, 35, 72, 60, 71, 72, 52, 50, 54, 11, 51, 18, 47,  5,  8,
#        37, 97, 20, 33,  1, 59,  1, 56,  1,  9, 57, 20, 79, 29, 16, 32, 54,
#        93, 10, 46, 59, 84, 76, 15, 10, 15,  0, 69,  4, 51, 51, 94, 36, 39,
#        62,  2, 24, 26, 35, 25, 87,  0, 55, 34, 38,  1, 45,  7, 93, 56, 38,
#        21, 51, 75, 81, 74, 33, 20, 37,  9, 40, 60, 31, 83, 50, 71, 67, 30,
#        66,  1, 43, 61, 23, 65, 84, 87, 46, 57, 16,  2, 28, 12, 96, 44, 76,
#        29, 75, 41, 87, 67, 61, 30,  5, 12, 62,  3, 83, 81,  6, 85,  4, 37,
#        57, 84, 39, 71, 61,  6, 76, 14, 31, 98, 40, 17, 51, 16, 42, 63, 86,
# ...

# %%
train
# Out:
#       margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0    0.007812  0.023438  0.023438  0.003906  0.011719  0.009766  0.027344
# 1    0.005859  0.000000  0.031250  0.015625  0.025391  0.001953  0.019531
# 2    0.005859  0.009766  0.019531  0.007812  0.003906  0.005859  0.068359
# 3    0.000000  0.003906  0.023438  0.005859  0.021484  0.019531  0.023438
# 4    0.005859  0.003906  0.048828  0.009766  0.013672  0.015625  0.005859
# ..        ...       ...       ...       ...       ...       ...       ...
# 985  0.060547  0.119140  0.007812  0.003906  0.000000  0.148440  0.017578
# 986  0.001953  0.003906  0.021484  0.107420  0.001953  0.000000  0.000000
# 987  0.001953  0.003906  0.000000  0.021484  0.078125  0.003906  0.007812
# 988  0.000000  0.000000  0.046875  0.056641  0.009766  0.000000  0.000000
# 989  0.023438  0.019531  0.031250  0.015625  0.005859  0.019531  0.035156
#
#      margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# ...

# %%
labels.shape[0]
# Out:
# 990

# %%
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
sss = StratifiedShuffleSplit(n_splits= 10, test_size=0.2, random_state=23)
sss.get_n_splits( train, labels)

for i, (train_index, test_index) in enumerate(sss.split(train, labels)):

    X_train, X_test = train.values[train_index], train.values[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
#for문 아래에서 같이 10번 실행해야함
classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="rbf", C=0.025, probability=True),
    NuSVC(probability=True),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis()]

# Logging for Visual Comparison
log_cols=["Classifier", "Accuracy", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = clf.predict(X_test)
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    train_predictions = clf.predict_proba(X_test)
    ll = log_loss(y_test, train_predictions)
    print("Log Loss: {}".format(ll))
    
    log_entry = pd.DataFrame([[name, acc*100, ll]], columns=log_cols)
    #log = log.concat(log_entry)
    log = pd.concat([log, log_entry])
    
print("="*30)

# %%
# Out:
# ...
# KNeighborsClassifier
# ****Results****
# Accuracy: 88.8889%
# Log Loss: 1.6363106238703065
# ...
# SVC
# ****Results****
# Accuracy: 85.8586%
# Log Loss: 4.641903606811855
# ...
# NuSVC
# ****Results****
# Accuracy: 92.9293%
# Log Loss: 2.3591102010249783
# ...
# DecisionTreeClassifier
# ****Results****
# Accuracy: 65.1515%
# Log Loss: 12.560667090146888
# ...
# RandomForestClassifier
# ****Results****
# Accuracy: 97.4747%
# Log Loss: 0.767259567448965
# ...
# AdaBoostClassifier
# ****Results****
# Accuracy: 3.0303%
# Log Loss: 4.434002143022803
# ...
# GradientBoostingClassifier
# ****Results****
# Accuracy: 70.2020%
# Log Loss: 2.057201673227711
# ...
# GaussianNB
# ****Results****
# Accuracy: 57.0707%
# Log Loss: 15.473285545881547
# ...
# LinearDiscriminantAnalysis
# ****Results****
# Accuracy: 97.9798%
# Log Loss: 0.2299344821364372
# ...
# QuadraticDiscriminantAnalysis
# ****Results****
# Accuracy: 2.5253%
# Log Loss: 35.13346012171519
# ...

# %%
sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

sns.set_color_codes("muted")
sns.barplot(x='Log Loss', y='Classifier', data=log, color="g")

plt.xlabel('Log Loss')
plt.title('Classifier Log Loss')
plt.show()

# %%
# Predict Test Set
favorite_clf = LinearDiscriminantAnalysis()
favorite_clf.fit(X_train, y_train)
test_predictions = favorite_clf.predict_proba(test)

# Format DataFrame
submission = pd.DataFrame(test_predictions, columns=classes)
submission.insert(0, 'id', test_ids)
submission.reset_index()

# Export Submission
#submission.to_csv('submission.csv', index = False)
submission.tail()
# Out:
#        id  Acer_Capillipes  Acer_Circinatum      Acer_Mono    Acer_Opalus  \
# 589  1576    1.458047e-172     1.000000e+00  3.467979e-209  1.206288e-144
# 590  1577    5.624086e-116    3.095328e-178  4.609025e-237   2.721686e-84
# 591  1579     1.166820e-86    3.222578e-169  1.108324e-130   2.606473e-43
# 592  1580    1.956462e-131    4.408520e-159  1.158982e-121   1.223869e-64
# 593  1583    2.384915e-183    9.554955e-214  2.835987e-149  3.771057e-108
#
#      Acer_Palmatum    Acer_Pictum  Acer_Platanoids    Acer_Rubrum  \
# 589  2.117626e-170  5.527569e-209    2.613918e-243  3.107253e-144
# 590   0.000000e+00  2.869993e-158    1.614067e-176   8.891737e-81
# 591   0.000000e+00   2.376348e-89    6.006980e-150  2.276487e-108
# 592  9.881313e-324  3.631523e-112    1.215048e-116   4.645240e-65
# 593   0.000000e+00   4.186946e-96    1.361951e-171  6.124627e-168
#
#      Acer_Rufinerve  ...  Salix_Fragilis  Salix_Intergra    Sorbus_Aria  \
# ...
